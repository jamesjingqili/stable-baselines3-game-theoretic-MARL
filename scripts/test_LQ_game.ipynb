# %%
import gymnasium as gym
import wandb
from wandb.integration.sb3 import WandbCallback
from stable_baselines3.common.callbacks import CheckpointCallback, CallbackList
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from torch import nn
import os
# Initialize a wandb run. The parameters below allow you to:
# - sync tensorboard logs (which SB3 produces)
# - automatically log environment videos if available
# generate a date time stamp for the run
run = wandb.init(
    project="mappo",   # Replace with your wandb project name
    entity="stable_baselines3_marl",       # (Optional) your wandb username or team name
    # id = "",          # Comment this out if you want a new run each time
    sync_tensorboard=True,              # Auto-upload tensorboard metrics
    monitor_gym=True,                   # Auto-upload videos of your agent (if env supports it)
    save_code=True,                     # (Optional) Save a snapshot of your code
)
# Specify the directory to save checkpoints
save_dir = "./models"
os.makedirs(save_dir, exist_ok=True)

vec_env = make_vec_env("LQR-v2", n_envs=4)


# Create a CheckpointCallback to save the model every 10,000 timesteps
checkpoint_callback = CheckpointCallback(
    save_freq=10_000,               # Save frequency in timesteps
    save_path=save_dir,            # Directory to save checkpoints
    name_prefix=run.id+"_"+vec_env.envs[0].spec.id+"/policy_checkpoint"
)
# Create a WandbCallback to log training metrics and videos
wandb_callback = WandbCallback()
# Combine the callbacks into a CallbackList
callback = CallbackList([checkpoint_callback, wandb_callback])
# Parallel environments
policy_kwargs = dict(
    activation_fn=nn.ReLU,  # Change activation function to ReLU
    net_arch=[dict(pi=[64, 64], vf=[64, 64])]
)

model = PPO("MlpPolicy", vec_env, policy_kwargs=policy_kwargs, verbose=1,tensorboard_log=f"runs/{run.id}")
model.learn(total_timesteps=8_00_000, callback=callback, )

run.finish()


# del model # remove to demonstrate saving and loading

# model = PPO.load("ppo_cartpole")
# Out:
# wandb: Currently logged in as: jingqi_li (stable_baselines3_marl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>/mnt/2312dd0d-0348-41b0-8596-b79a2cc21f6b/github/stable-baselines3-game-theoretic-MARL/scripts/wandb/run-20250204_222517-4qoztds1</code>
# Syncing run <strong><a href='https://wandb.ai/stable_baselines3_marl/mappo/runs/4qoztds1' target="_blank">classic-grass-4</a></strong> to <a href='https://wandb.ai/stable_baselines3_marl/mappo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/stable_baselines3_marl/mappo' target="_blank">https://wandb.ai/stable_baselines3_marl/mappo</a>
#  View run at <a href='https://wandb.ai/stable_baselines3_marl/mappo/runs/4qoztds1' target="_blank">https://wandb.ai/stable_baselines3_marl/mappo/runs/4qoztds1</a>
# /mnt/2312dd0d-0348-41b0-8596-b79a2cc21f6b/sb3game/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment LQR-v2 is out of date. You should consider upgrading to version `v3`.
#   logger.deprecation(
# /mnt/2312dd0d-0348-41b0-8596-b79a2cc21f6b/github/stable-baselines3-game-theoretic-MARL/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cuda device
# Logging to runs/4qoztds1/PPO_1
# /mnt/2312dd0d-0348-41b0-8596-b79a2cc21f6b/github/stable-baselines3-game-theoretic-MARL/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.9     |
# |    ep_rew_mean     | 61.7     |
# | time/              |          |
# |    fps             | 8493     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.9        |
# |    ep_rew_mean          | 63.7        |
# | time/                   |             |
# |    fps                  | 4576        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006097003 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | -0.00109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.24        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00642    |
# |    std                  | 1           |
# |    value_loss           | 97.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.7        |
# |    ep_rew_mean          | 89.1        |
# | time/                   |             |
# |    fps                  | 4111        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008880469 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 1           |
# |    value_loss           | 37.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 3908         |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0123091955 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0178      |
# |    std                  | 0.991        |
# |    value_loss           | 44.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 3792        |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013970278 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.983       |
# |    value_loss           | 64          |
# -----------------------------------------
# /mnt/2312dd0d-0348-41b0-8596-b79a2cc21f6b/github/stable-baselines3-game-theoretic-MARL/stable_baselines3/common/save_util.py:284: UserWarning: Path 'models/4qoztds1_LQR-v2' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 3723        |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015620368 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.969       |
# |    value_loss           | 63.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 355         |
# | time/                   |             |
# |    fps                  | 3675        |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015187187 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.954       |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | 436         |
# | time/                   |             |
# |    fps                  | 3641        |
# |    iterations           | 8           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016028896 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.47        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.931       |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 291         |
# |    ep_rew_mean          | 485         |
# | time/                   |             |
# |    fps                  | 3597        |
# |    iterations           | 9           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013763372 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.905       |
# |    value_loss           | 9.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 521         |
# | time/                   |             |
# |    fps                  | 3564        |
# |    iterations           | 10          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.014511704 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.17       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.875       |
# |    value_loss           | 5.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 531         |
# | time/                   |             |
# |    fps                  | 3544        |
# |    iterations           | 11          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012354794 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.515       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.846       |
# |    value_loss           | 3.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 539         |
# | time/                   |             |
# |    fps                  | 3522        |
# |    iterations           | 12          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013602057 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.808       |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 545         |
# | time/                   |             |
# |    fps                  | 3503        |
# |    iterations           | 13          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.014443091 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.519       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.773       |
# |    value_loss           | 2.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 550         |
# | time/                   |             |
# |    fps                  | 3497        |
# |    iterations           | 14          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012628091 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.875       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.742       |
# |    value_loss           | 1.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 553         |
# | time/                   |             |
# |    fps                  | 3490        |
# |    iterations           | 15          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.013247048 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.453       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.711       |
# |    value_loss           | 1.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 557         |
# | time/                   |             |
# |    fps                  | 3485        |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.015063755 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.316       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.681       |
# |    value_loss           | 0.815       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 560         |
# | time/                   |             |
# |    fps                  | 3472        |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.012822306 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.215       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00834    |
# |    std                  | 0.653       |
# |    value_loss           | 0.614       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 563         |
# | time/                   |             |
# |    fps                  | 3462        |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.014196714 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.195       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.622       |
# |    value_loss           | 0.515       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 565         |
# | time/                   |             |
# |    fps                  | 3459        |
# |    iterations           | 19          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.016001161 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0568      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.595       |
# |    value_loss           | 0.366       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 567         |
# | time/                   |             |
# |    fps                  | 3457        |
# |    iterations           | 20          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.016797135 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0986      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.568       |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 570         |
# | time/                   |             |
# |    fps                  | 3454        |
# |    iterations           | 21          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.016308922 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00735     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.541       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 572         |
# | time/                   |             |
# |    fps                  | 3452        |
# |    iterations           | 22          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.016268041 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.514       |
# |    value_loss           | 0.185       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 574         |
# | time/                   |             |
# |    fps                  | 3450        |
# |    iterations           | 23          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.017189477 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.038       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.488       |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 576         |
# | time/                   |             |
# |    fps                  | 3448        |
# |    iterations           | 24          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.017291762 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0626      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.465       |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 578         |
# | time/                   |             |
# |    fps                  | 3446        |
# |    iterations           | 25          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.017680358 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.444       |
# |    value_loss           | 0.0978      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 579         |
# | time/                   |             |
# |    fps                  | 3440        |
# |    iterations           | 26          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.015619839 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0476      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.425       |
# |    value_loss           | 0.0832      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 581         |
# | time/                   |             |
# |    fps                  | 3434        |
# |    iterations           | 27          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.020032454 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00573    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.405       |
# |    value_loss           | 0.0642      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 582         |
# | time/                   |             |
# |    fps                  | 3429        |
# |    iterations           | 28          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.018697388 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0341      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.385       |
# |    value_loss           | 0.0512      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 583         |
# | time/                   |             |
# |    fps                  | 3429        |
# |    iterations           | 29          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.015589053 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00835     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.367       |
# |    value_loss           | 0.044       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 584         |
# | time/                   |             |
# |    fps                  | 3426        |
# |    iterations           | 30          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.020305317 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0332     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.35        |
# |    value_loss           | 0.0382      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 585         |
# | time/                   |             |
# |    fps                  | 3422        |
# |    iterations           | 31          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.017129706 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0472     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.333       |
# |    value_loss           | 0.0301      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 586         |
# | time/                   |             |
# |    fps                  | 3418        |
# |    iterations           | 32          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.018457025 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.318       |
# |    value_loss           | 0.0229      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 587        |
# | time/                   |            |
# |    fps                  | 3414       |
# |    iterations           | 33         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.01756019 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.939     |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0352     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0144    |
# |    std                  | 0.303      |
# |    value_loss           | 0.0194     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 588         |
# | time/                   |             |
# |    fps                  | 3410        |
# |    iterations           | 34          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.019864667 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.288       |
# |    value_loss           | 0.0169      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 589         |
# | time/                   |             |
# |    fps                  | 3407        |
# |    iterations           | 35          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.018898558 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00109     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.275       |
# |    value_loss           | 0.014       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 589         |
# | time/                   |             |
# |    fps                  | 3403        |
# |    iterations           | 36          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.019270204 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0474     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.262       |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 589         |
# | time/                   |             |
# |    fps                  | 3401        |
# |    iterations           | 37          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.020798799 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.169      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0377     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.25        |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 590         |
# | time/                   |             |
# |    fps                  | 3398        |
# |    iterations           | 38          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.020579616 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0209      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.238       |
# |    value_loss           | 0.00861     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 590         |
# | time/                   |             |
# |    fps                  | 3395        |
# |    iterations           | 39          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.017908817 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.196       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0513     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00789     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 591         |
# | time/                   |             |
# |    fps                  | 3392        |
# |    iterations           | 40          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.020515501 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.378       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00234    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.218       |
# |    value_loss           | 0.0067      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 591         |
# | time/                   |             |
# |    fps                  | 3390        |
# |    iterations           | 41          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.029433701 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.564       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.207       |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 3387        |
# |    iterations           | 42          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.020119492 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.764       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.198       |
# |    value_loss           | 0.00541     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 3385        |
# |    iterations           | 43          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.019240143 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.937       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.189       |
# |    value_loss           | 0.00508     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 3383        |
# |    iterations           | 44          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.026302295 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.13        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.18        |
# |    value_loss           | 0.00581     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 3383        |
# |    iterations           | 45          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.027194992 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.32        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000953    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.172       |
# |    value_loss           | 0.0044      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 592        |
# | time/                   |            |
# |    fps                  | 3382       |
# |    iterations           | 46         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.02289481 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.51       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0354    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00989   |
# |    std                  | 0.164      |
# |    value_loss           | 0.00453    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 3380        |
# |    iterations           | 47          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.023530547 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.68        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.157       |
# |    value_loss           | 0.00447     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 3378        |
# |    iterations           | 48          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.024398547 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.85        |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0233      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.15        |
# |    value_loss           | 0.00374     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 593         |
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 49          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.028513135 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.01        |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.144       |
# |    value_loss           | 0.00401     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 593         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 50          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.020832956 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.18        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00176    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00935    |
# |    std                  | 0.139       |
# |    value_loss           | 0.00417     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 593         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 51          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.033668384 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.36        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00557    |
# |    std                  | 0.132       |
# |    value_loss           | 0.00339     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 593        |
# | time/                   |            |
# |    fps                  | 3374       |
# |    iterations           | 52         |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.03074859 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.54       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0091     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0127    |
# |    std                  | 0.127      |
# |    value_loss           | 0.00398    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 593        |
# | time/                   |            |
# |    fps                  | 3374       |
# |    iterations           | 53         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 434176     |
# | train/                  |            |
# |    approx_kl            | 0.03068404 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.69       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0271    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00838   |
# |    std                  | 0.122      |
# |    value_loss           | 0.00431    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 594         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 54          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.021549765 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.84        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00101     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00476    |
# |    std                  | 0.118       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 594         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 55          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.031053655 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.99        |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00704    |
# |    std                  | 0.113       |
# |    value_loss           | 0.00355     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 593         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 56          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.050952733 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.14        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00351    |
# |    std                  | 0.108       |
# |    value_loss           | 0.00504     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 593         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 57          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.033349548 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.32        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00844    |
# |    std                  | 0.104       |
# |    value_loss           | 0.00404     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 593         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 58          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.026497759 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.44        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00425    |
# |    std                  | 0.101       |
# |    value_loss           | 0.00329     |
# -----------------------------------------

# %%
# model.save("ppo_LQR_v3")
vec_env.envs[0]
# Out:
# <Monitor<TimeLimit<OrderEnforcing<PassiveEnvChecker<LQR_Env2<LQR-v2>>>>>>

# %%
# visualize the trained agent's value function

import torch as th

# Create your environment and model (example with CartPole)
env = make_vec_env("LQR-v2", n_envs=1)
gym_env = gym.make("LQR-v2")
# Assume you have a state (observation) as a NumPy array.
# For a single state from CartPole, the shape is usually (4,).
state = env.reset()[0]  # Take the first observation from the vectorized env

# Convert state to a PyTorch tensor and add a batch dimension
obs_tensor = th.as_tensor(state).float().unsqueeze(0).to(model.device)

# Disable gradient calculations for evaluation
with th.no_grad():
    # The forward pass of the policy typically returns a tuple.
    # For actor–critic policies, the tuple is usually:
    # (action_distribution or action, value, log_probability) 
    # (depending on the implementation)
    # Here we extract the value estimate.
    _, value, _ = model.policy(obs_tensor)

# Since value is a tensor with a batch dimension, get the scalar value
print("Estimated value:", value.item())
# Out:
# Estimated value: 195.56361389160156
# /mnt/2312dd0d-0348-41b0-8596-b79a2cc21f6b/sb3game/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment LQR-v2 is out of date. You should consider upgrading to version `v3`.
#   logger.deprecation(

# %%
model.policy.eval()
# model.policy.train()
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=8, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=8, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=4, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
# plot the value function for x and y ranging from -2 to 2
import numpy as np

# Create a grid of (x, y) coordinates
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)
# Stack the coordinates to a NumPy array of shape (n_points, 2)
Z = np.stack((X, Y), axis=-1).reshape(-1, 2)
# Get the value estimates
values = np.zeros((100, 100))
for ii, xx in enumerate(x):
    for jj, yy in enumerate(y):
        state = np.array([xx, yy, 0, 0, 1,1,0,0])
        obs_tensor = th.as_tensor(state).float().unsqueeze(0).to(model.device)
        with th.no_grad():
            _, value, _ = model.policy(obs_tensor)
            values[ii, jj] = value.item()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
# plt.imshow(values, extent=(-2, 2, -2, 2))
# plot the surface
plt.imshow(values, extent=(-2, 2, -2, 2), origin='lower')
plt.colorbar(label='Value')
plt.xlabel('Position')
plt.ylabel('Velocity')
plt.title('Value Function')
plt.show()

# %%
model.load("./models/4qoztds1_LQR-v2/policy_checkpoint_10000_steps.zip")

# %%
# simulate the trajectory of an agent in the environment
initial_state = np.array([-1,-1,0,0,1,1,0,0])
x0 = gym_env.reset(options = {"initial_state": initial_state})[0]
# we do simulation
horizon = 100
x_traj = np.zeros((horizon+1, env.observation_space.shape[0]))
x_traj[0] = x0
rew_traj = np.zeros(horizon)
for t in range(0, horizon):
    action, _ = model.predict(x_traj[t])
    x_traj[t+1], rew_traj[t], _, _, _ = gym_env.step(action)

# %%
# plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(x_traj[:, 0], x_traj[:, 1], 'b')
plt.plot(x_traj[0, 0], x_traj[0, 1], 'go', label='start')
plt.plot(x_traj[-1, 0], x_traj[-1, 1], 'ro', label='end')
plt.plot(x_traj[:, 4], x_traj[:, 5], 'r')
plt.plot(x_traj[0, 4], x_traj[0, 5], 'go', label='start')
plt.plot(x_traj[-1, 4], x_traj[-1, 5], 'ro', label='end')
